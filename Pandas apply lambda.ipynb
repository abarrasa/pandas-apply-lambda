# %%
import pandas as pd
import numpy as np
import re

# %% [markdown]
# ## Challenge 1

# %%
dataset = pd.read_csv('./data/input/IMDB-Movie-Data.csv')
dataset
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
dataset_votes = dataset['Votes']
dataset_votes
# Out:
# 0      757074
# 1      485820
# 2      157606
# 3       60545
# 4      393727
#         ...
# 995     27585
# 996     73152
# 997     70699
# 998      4881
# 999     12435
# Name: Votes, Length: 1000, dtype: int64

# %%
def create_bins(dataset_votes):
    if dataset_votes >= 0 and dataset_votes <= 999:
        return 1
    elif dataset_votes >= 1000 and dataset_votes <= 9999:
        return 2
    elif dataset_votes >= 10000 and dataset_votes <= 99999:
        return 3
    elif dataset_votes >= 100000 and dataset_votes <= 999999:
        return 4
    elif dataset_votes >= 1000000:
        return 5 
    else:
        return "Error"

# %%
bin = dataset["Votes"].apply(create_bins)
bin #hemos creado una serie pero no la hemos includio en el dataframe
# Out:
# 0      4
# 1      4
# 2      4
# 3      3
# 4      4
#       ..
# 995    3
# 996    3
# 997    3
# 998    2
# 999    3
# Name: Votes, Length: 1000, dtype: int64

# %%
dataset["bin"] = dataset["Votes"].apply(create_bins)

# %%
dataset
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Challenge 2

# %% [markdown]
# We want to know how much is the revenue per minute for every movie.

# %%
def division(x,y):
    return x/y

# %%
dataset['Revenue per minute'] = dataset.apply(lambda x: division(x['Revenue (Millions)'], x['Runtime (Minutes)']), axis=1)
dataset['Revenue per minute']
# Out:
# 0      2.753140
# 1      1.019839
# 2      1.180513
# 3      2.502963
# 4      2.642439
#          ...
# 995         NaN
# 996    0.186596
# 997    0.591939
# 998         NaN
# 999    0.225747
# Name: Revenue per minute, Length: 1000, dtype: float64

# %% [markdown]
# ## Challenge 3

# %% [markdown]
# We want to create a new ranking where we add 1 point if the genre is thriller but subtract 1 point if the genre is comedy.

# %%
def new_ranking(x,y):
    if 'Thriller' in x:
        return y +1
    elif 'Comedy' in x:
        return y -1
    else: 
        return y

# %%
dataset['Rating'] = dataset.apply(lambda x: new_ranking(x['Genre'], x['Rating']), axis=1)
dataset
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ## Challenge 4

# %% [markdown]
# We want to know if the sum of the ASCII value of every character of the movie title divided by the number of votes retrieve a prime number...remember, prime numbers are integers.

# %%
def prime(title, votes):
    sum_title = 0
